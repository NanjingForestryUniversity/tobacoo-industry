# %%
import pickle

import numpy as np

from models import SpecDetector, evaluation_and_report
from utils import visualization_evaluation

# %%
blk_sz, sensitivity = 8, 8
selected_bands = [127, 201, 202, 294]
tree_num = 185

# %%
dataset_file = f'./dataset/data_{blk_sz}x{blk_sz}_c{len(selected_bands)}_sen{sensitivity}_7.p'
model_file = f'./models/rf_{blk_sz}x{blk_sz}_c{len(selected_bands)}_{tree_num}_7.model'

# %%
with open(dataset_file, 'rb') as f:
    x_list, y_list = pickle.load(f)
x, y = np.asarray(x_list), np.asarray(y_list, dtype=int)

# %%
model = SpecDetector(model_path=model_file, blk_sz=blk_sz, channel_num=len(selected_bands))
# 画图验证效果
visualization_evaluation(detector=model, data_path=r'F:\zhouchao\618\tobacco', selected_bands=selected_bands)

evaluation_and_report(model, x, y)
# Out:
# C:\Users\FEIJINTI\PycharmProjects\tobacco-sorting-industry\models.py:125: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   blocks = np.array(blocks)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       2 # 画图验证效果
#       3 visualization_evaluation(detector=model, data_path=r'F:\zhouchao\618\tobacco', selected_bands=selected_bands)
# ----> 5 evaluation_and_report(model, x, y)
#
# File ~\PycharmProjects\tobacco-sorting-industry\models.py:52, in evaluation_and_report(model, test_x, test_y)
#      50 def evaluation_and_report(model, test_x, test_y):
#      51     t1 = time.time()
# ---> 52     y_pred = model.predict(test_x)
#      53     y_pred_binary = np.ones_like(y_pred)
#      54     y_pred_binary[(y_pred == 0) | (y_pred == 1)] = 0
#
# File ~\PycharmProjects\tobacco-sorting-industry\models.py:125, in SpecDetector.predict(self, data)
#     123 def predict(self, data):
#     124     blocks = split_x(data, blk_sz=self.blk_sz)
# --> 125     blocks = np.array(blocks)
#     126     features = feature(np.array(blocks))
#     127     y_pred = self.clf.predict(features)
#
# ValueError: could not broadcast input array from shape (8,8,8,4) into shape (8,)
